# %%
# picture of problem 
# source https://math.stackexchange.com/questions/45952/why-do-we-take-a-derivative
# https://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/highlights_of_calculus/big-picture-derivatives/

# %%
from sympy import *
x,h = symbols('x h')

# %%
#(2,16)
#(4,18)
x0 = 2 ; y0 = 16 
x1 = 4 ; y1 = 18
x2 = 6 ; y2 = 19
m0 = int((y0-y1)/(x0-x1))
# y - y0 = m(x - x0)

# %%
def f(x):
    return x**2

# %%
f(x)
# Out:
# x**2

# %%
f(x.subs(x,5))
# Out:
# 25

# %%
plot(f(x))

# %%
plot(f(sin(x)))

# %%
plot(f(cos(x)))

# %%
plot(f(tan(x)))

# %%
plot(f(sec(x)))

# %%
plot(f(cot(x)))

# %%
plot(f(csc(x)))

# %%
plot(f(asin(x)))
