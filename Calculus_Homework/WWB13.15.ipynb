# %%
from IPython.display import Image
from IPython.core.display import HTML 
from sympy import *; x,h,y,t = symbols("x h y t")
Image(url= "https://i.imgur.com/8q79db3.png")
# Out:
# <img src="https://i.imgur.com/8q79db3.png"/>

# %%
# source https://nathancarter.github.io/how2data/site/how-to-find-the-critical-numbers-of-a-function-in-python-using-sympy/
f = x**6 + (6/x)
d = diff(f)
#solve(Eq(d,0)), 
f.subs(x,2.5), f.subs(x,6),
# Out:
# (246.540625000000, 46657)

# %%
p = plot(f,d,show = False, legend = True, )#xlim = (-0.4,0.4), ylim = (-110,110))
p[1].line_color = 'red'
p.show()

# %%
Image(url= "https://i.imgur.com/2wIXsU7.png")
# Out:
# <img src="https://i.imgur.com/2wIXsU7.png"/>
