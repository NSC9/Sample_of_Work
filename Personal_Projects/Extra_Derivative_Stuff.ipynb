# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
Image(url= "https://i.imgur.com/OKzEasd.png")
# Out:
# <img src="https://i.imgur.com/OKzEasd.png"/>

# %%
from sympy import *
from sympy import euler
x = symbols('x')
c = symbols('c', real = True)
sympify(c).is_real
# Out:
# True

# %%
eq5 = c*E**(x)
Eq(eq5,100) #solving for c when x = 10 because the plot looks nice
# Out:
# Eq(c*exp(x), 100)

# %%
factorial??

# %%
eq = x**x
Eq(Derivative(eq).doit(),E**(log(x)*x))
# Out:
# Eq(x**x*(log(x) + 1), exp(x*log(x)))

# %%
E**log(x)
# Out:
# x

# %%
for x in range(1,10):
   print(x**x)
# Out:
# 1
# 4
# 27
# 256
# 3125
# 46656
# 823543
# 16777216
# 387420489

# %%
for x in range(1,10):
    print((x**x)*(log(x)+1).evalf())
# Out:
# 1.00000000000000
# 6.77258872223978
# 56.6625317940390
# 610.891356446692
# 8154.49347635656
# 130252.329796304
# 2426083.68188346
# 51664455.9041356
# 1238670309.19442

# %%
import math
x = symbols('x')
f = (x**x)*(log(x)+1)
#plot(x**x, f,yscale='log',xlim = (-1,10),line_color=1,legend=True)

p1 = plot(x**x, show=False,line_color=lambda x:math.cos(x), title="Derivatives of x**x",yscale='log',xscale='log',size = (9,5))
p2 = plot(f, show = False,line_color=lambda x:math.cos(x))
p3 = plot(diff(x**x,x,2),show=False,line_color=lambda x:math.cos(x))
p4 = plot(diff(x**x,x,3),show=False,line_color=lambda x:math.cos(x))

p5 = plot(diff(x**x,x,4),show=False,line_color=lambda x:math.cos(x))
p6 = plot(diff(x**x,x,5),show=False,line_color=lambda x:math.cos(x))
p7 = plot(diff(x**x,x,6),show=False,line_color=lambda x:math.cos(x))
p8 = plot(diff(x**x,x,7),show=False,line_color=lambda x:math.cos(x))
p9 = plot(diff(x**x,x,8),show=False,line_color=lambda x:math.cos(x))


p1.extend(p2)
p1.extend(p3)
p1.extend(p4)
p1.extend(p5)
p1.extend(p6)
p1.extend(p7)
p1.extend(p8)
p1.extend(p9)

p1.show()
# Out:
# c:\users\nick c\appdata\local\programs\python\python39\lib\site-packages\sympy\plotting\plot.py:665: RuntimeWarning: invalid value encountered in log10
#   xnew = 10**(np.log10(p[0]) + random * (np.log10(q[0]) -
# c:\users\nick c\appdata\local\programs\python\python39\lib\site-packages\sympy\plotting\plot.py:666: RuntimeWarning: invalid value encountered in log10
#   np.log10(p[0])))
# <string>:1: RuntimeWarning: overflow encountered in power
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
Derivative(x**x) > x**x
# Out:
# Derivative(x**x, x) > x**x

# %%
(Derivative(x**x,x,2)> Derivative(x**x,x,1))
# Out:
# Derivative(x**x, (x, 2)) > Derivative(x**x, x)

# %%
(Derivative(x**x,x,2)> Derivative(x**x,x,1)).doit()
# Out:
# x**x*((log(x) + 1)**2 + 1/x) > x**x*(log(x) + 1)

# %%
(Derivative(x**x,x,4)> Derivative(x**x,x,3)).doit()
# Out:
# x**x*((log(x) + 1)**4 + 6*(log(x) + 1)**2/x - 4*(log(x) + 1)/x**2 + 3/x**2 + 2/x**3) > x**x*((log(x) + 1)**3 + 3*(log(x) + 1)/x - 1/x**2)

# %%
from sympy import oo
n = symbols('n')
Limit(Derivative(x**x,x,n),n,oo)  # this does not display what I want accurately in LaTeX
# Out:
# Limit(Derivative(x**x, x, n), n, oo, dir='-')

# %%
log(x,x**x)
# Out:
# log(x)/log(x**x)

# %%
for i in range(2,5):
    print(log(x,i**i))
# Out:
# log(x)/log(4)
# log(x)/log(27)
# log(x)/log(256)

# %%
Eq(Derivative(log(x,x**x)),Derivative(log(x,x**x)).doit())
# Out:
# Eq(Derivative(log(x)/log(x**x), x), (-log(x) - 1)*log(x)/log(x**x)**2 + 1/(x*log(x**x)))

# %%
Limit(x,x,2)
# Out:
# Limit(x, x, 2)

# %%
Eq(Derivative(E**(log(x)*x)),Derivative(E**(log(x)*x)).doit())

# %%
Eq(((x**x)/(E**x)),simplify(((x**x)/(E**x))))

# %%
((E**x)/(x**x))

# %%
factorial(x).compare(simplify(((x**x)/(E**x))))
# -1 for smaller, 0 for equal and 1 for greater

# %%
(factorial(x) > ((x**x)/(E**x))).simplify()

# %%
plot(x**x,Derivative(eq).doit(),yscale='log') # after plotting this I noticed that it would be nice if this y= 100 right when x = 10
                 # the final solution may be useful for conceptualizing percentage of exponential growths

# %%
log(10**4).evalf()

# %%
Image(url= "https://i.imgur.com/F2uZGSM.png")

# %%
eq11 = Eq(c*E**(10),100) 
eq11
# This is what I want to solve.

# %%
eq1 = 0.00453999208646404*exp(x)
Eq(eq1,eq1.subs(x,10).evalf())

# %%
eq2 = 0.00454*exp(x)
Eq(eq2,eq2.subs(x,10).evalf())

# %%
p0 = plot(eq1,eq2,show = False,xlim = (0,10),size = (12,5),legend = True,autoscale = True)
p0[0].line_color = 'r'
p0[1].line_color = 'b'
p0.show()

# %%
s = solve(eq11)[0]
s # one possible solution for real number c when x = 10

# %%
s.evalf()

# %%
final_solution = (s*E**x)
phi = symbols('phi')
Eq(phi,final_solution)

# %%
final_solution.subs(x,10)

# %%
final_equation = s.evalf()*E**x
Eq(final_equation,100)

# %%
(0.00453999297624849*E**10).evalf()

# %%
p0 = plot(eq1,eq2,final_solution,show = False,xlim = (0,10),size = (12,5),legend = True,autoscale = True)
p0[0].line_color = 'r'
p0[1].line_color = 'b'
p0[2].line_color = 'g'
p0.show()

# %%
eq14 = Eq(0.00453999297624849*E**(x),100) 
solve(eq14)

# %%
0.00453999208646404 < 0.00453999297624849 < 0.00454
