# %% [markdown]
# # Donate With Crypto:
# Bitcoin (BTC): **bc1qtrjmtsfxhmjmu4wwdh03u92gpy662rnt3drlm7**
#
# Ethereum (ETH): **0x8B20704BB59E985Ad85D2477A9aB85a6F499F9E8**
#
# Binance (BNB/BEP20): **0x8B20704BB59E985Ad85D2477A9aB85a6F499F9E8**
#
# **Made by https://github.com/NSC9**

# %%
import random
from sympy import *
for i in range(1,10):
    k=0
    def random_value(k):
        return random.choice([k for k in range(2,10) if k not in [0]])
    size1 = random_value(k)
    size2 = random_value(k)
    M0 = MatrixSymbol('M_%i'%i,size1,size1)
    M1 = MatrixSymbol('M^-1_%i'%i,size1,size1)
    M = randMatrix(size1,size1,percent=100,min=1, max=10,symmetric=False)
    if det(M) != 0:
        display(Eq(M0,M))
        display(Eq(M1, M.inv()))
    else:
        pass
# Out:
# Eq(M_1, Matrix([
# [6, 9,  9,  4,  5, 1,  8, 6, 5],
# [9, 1,  1,  3,  5, 9,  3, 4, 2],
# [3, 8,  1,  3,  3, 1,  2, 4, 4],
# [6, 2,  1,  9,  4, 8,  5, 2, 1],
# [5, 2,  9,  5,  7, 5,  4, 7, 4],
# [7, 4,  5,  4,  1, 2,  2, 7, 3],
# [3, 5,  3,  5, 10, 2,  3, 9, 1],
# [4, 4, 10, 10,  9, 1, 10, 2, 1],
# [1, 1,  7,  6,  4, 6,  5, 6, 6]]))
# Eq(M^-1_1, Matrix([
# [ -458608/3066019,  1225591/6132038,  588289/6132038,  -597401/3066019,  -783073/6132038,  486320/3066019, -363807/6132038,  1029951/6132038,   43731/3066019],
# [  685692/3066019, -1458307/6132038, -114739/6132038,   899494/3066019,  1686591/6132038, -520464/3066019,   29033/6132038, -1382083/6132038, -629239/3066019],
# [  421508/3066019, -1268257/6132038, -533879/6132038,   585041/3066019,  2171305/6132038, -307920/3066019, -329493/6132038,  -891195/6132038, -527512/3066019],
# ...
