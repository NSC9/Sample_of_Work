# %%
from IPython.display import Image
from IPython.core.display import HTML 
from sympy import *
Image(url= "https://i.imgur.com/bigiQyZ.png",width = 800)
# Out:
# <img src="https://i.imgur.com/bigiQyZ.png" width="800"/>

# %%
x = symbols('x')
f = lambda x: 3+sqrt(4-x**2)
integrate(f(x), (x, -2, 0))
# Out:
# pi + 6

# %%
Image(url= "https://i.imgur.com/RsS9Bs9.png",width = 600)
# Out:
# <img src="https://i.imgur.com/RsS9Bs9.png" width="600"/>

# %%
print("""
Why does this work? 
""")
# Out:
# Why does this work?

# %%
print("""
Explanation
    ===========

    Compute definite or indefinite integral of one or more variables
    using Risch-Norman algorithm and table lookup. This procedure is
    able to handle elementary algebraic and transcendental functions
    and also a huge class of special functions, including Airy,
    Bessel, Whittaker and Lambert.
              
              - Sympy 
""")
# Out:
# Explanation
# ...
#
#     Compute definite or indefinite integral of one or more variables
#     using Risch-Norman algorithm and table lookup. This procedure is
#     able to handle elementary algebraic and transcendental functions
#     and also a huge class of special functions, including Airy,
#     Bessel, Whittaker and Lambert.
#
#               - Sympy

# %%
Image(url= "https://i.imgur.com/ry2eTRF.png",width = 700)
# Out:
# <img src="https://i.imgur.com/ry2eTRF.png" width="700"/>

# %%
Image(url= "https://i.imgur.com/mII09N7.png")
# Out:
# <img src="https://i.imgur.com/mII09N7.png"/>

# %%
Image(url= "https://i.imgur.com/LM0YPk0.png")
# Geddes, Keith O.; Czapor, Stephen R.; Labahn, George (1992). Algorithms for computer algebra.
# Boston, MA: Kluwer Academic Publishers. pp. xxii+585. Bibcode:1992afca.book.....G.
# doi:10.1007/b102438. ISBN 0-7923-9259-0.
# Out:
# <img src="https://i.imgur.com/LM0YPk0.png"/>

# %%
Image(url= "https://i.imgur.com/WvDPZVd.png")
# Geddes, Keith O.; Czapor, Stephen R.; Labahn, George (1992). Algorithms for computer algebra.
# Boston, MA: Kluwer Academic Publishers. pp. xxii+585. Bibcode:1992afca.book.....G.
# doi:10.1007/b102438. ISBN 0-7923-9259-0.
# Out:
# <img src="https://i.imgur.com/WvDPZVd.png"/>

# %%
Image(url= "https://i.imgur.com/hpTqp6y.png")
# Out:
# <img src="https://i.imgur.com/hpTqp6y.png"/>

# %%
Image(url= "https://i.imgur.com/oAg42Yv.png")
# Out:
# <img src="https://i.imgur.com/oAg42Yv.png"/>

# %%
Image(url= "https://i.imgur.com/FafOM08.png")
# Out:
# <img src="https://i.imgur.com/FafOM08.png"/>

# %%
Image(url= "https://i.imgur.com/pF0qiWx.png")
# https://www.mathsisfun.com/sets/function-hyperbolic.html
# Out:
# <img src="https://i.imgur.com/pF0qiWx.png"/>

# %%
Image(url= "https://i.imgur.com/7BqKMkQ.png")
# Out:
# <img src="https://i.imgur.com/7BqKMkQ.png"/>

# %%
Image(url= "https://i.imgur.com/zAldxXR.png")
# https://en.wikipedia.org/wiki/Integral#Leibniz_and_Newton
# Out:
# <img src="https://i.imgur.com/zAldxXR.png"/>

# %%
Image(url= "https://i.imgur.com/NpHmK4C.png")
# https://en.wikipedia.org/wiki/Fundamental_theorem_of_calculus#Examples
# Out:
# <img src="https://i.imgur.com/NpHmK4C.png"/>

# %%
Image(url= "https://i.imgur.com/4eZyUQQ.png")
# https://en.wikipedia.org/wiki/Fundamental_theorem_of_calculus#Examples
# Out:
# <img src="https://i.imgur.com/4eZyUQQ.png"/>

# %%
Image(url="https://i.imgur.com/Ls1kT7h.png")
# Out:
# <img src="https://i.imgur.com/Ls1kT7h.png"/>

# %%
Image(url="https://i.imgur.com/eSBsDjJ.png")
# https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9
# Out:
# <img src="https://i.imgur.com/eSBsDjJ.png"/>

# %%
Image(url="https://i.imgur.com/pHHeOjx.png")
#https://en.wikipedia.org/wiki/Integral_curve
# Out:
# <img src="https://i.imgur.com/pHHeOjx.png"/>

# %%
from sympy import *
x, y = symbols('x y')
f = lambda x,y: y-x**2
f(x,y)
# Out:
# -x**2 + y

# %%
from sympy.plotting import plot, plot3d, PlotGrid
plot3d(f(x*cos(y),y*sin(x)))

# %%
from sympy.plotting import plot, plot3d, PlotGrid
from sympy import symbols,cos,sin
x, y = symbols('x y')
f = lambda x,y: y-x**2
plot3d(f(x*cos(y),y*sin(x)))

# %%
from sympy.plotting import plot, plot3d, PlotGrid
from sympy import symbols,cos,sin
x, y = symbols('x y')
f = lambda x,y: y-x**2
f(x,y)
# Out:
# -x**2 + y

# %%
e0 = f(x*cos(y),y*sin(x))
e0
# Out:
# -x**2*cos(y)**2 + y*sin(x)

# %%
y
# Out:
# y

# %%
x
# Out:
# x

# %%
plot3d(e0)

# %%
print(e0 )
# Out:
# -x**2*cos(y)**2 + y*sin(x)

# %%
e1 = -x**2*cos(y)**2 + y*sin(x)
e1
# Out:
# -x**2*cos(y)**2 + y*sin(x)

# %%
e1**10
# Out:
# (-x**2*cos(y)**2 + y*sin(x))**10

# %%
plot3d(e1**10)

# %%
i = symbols('i')
e1**(i/10)
# Out:
# (-x**2*cos(y)**2 + y*sin(x))**(i/10)

# %%
for i in range(10,1,-1):   # start at 10, end at 1, descend
    plot3d(e1**(i/10))
