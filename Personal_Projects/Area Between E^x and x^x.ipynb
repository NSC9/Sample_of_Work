# %%
from sympy import E,plot,Eq,solve,Integral,diff
from sympy.abc import x
f = E**x
f
# Out:
# exp(x)

# %%
g = x**x
g
# Out:
# x**x

# %%
plot(x**x,E**x,yscale='log', xlim = (-1,3),ylim = (10**-0.2,10**1.3),size = (12,5),legend = True)
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars

# %%
# Step 1:
# Set f(x) = g(x) to find points of intersection
eq2 = Eq(f,g)
eq2
# Out:
# Eq(exp(x), x**x)

# %%
solve(eq2)[0]
# Out:
# E

# %%
# Step 2: Find the area between both curves
Integral(f-g,(x,1,E))
# Out:
# Integral(-x**x + exp(x), (x, 1, E))

# %%
Integral(f-g,(x,1,E)).evalf()
# Out:
# 4.47568828838871

# %%
# Now finding the area between their derivatives
plot(diff(x**x),diff(E**x),yscale='log', xlim = (-1,3),ylim = (10**-2,10**1.3),size = (12,5),legend = True)
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars

# %%
# Step 1:
# Set f'(x) = g'(x) to find points of intersection
eq3 = Eq(diff(f),diff(g))
eq3
# Out:
# Eq(exp(x), x**x*(log(x) + 1))

# %%
solve(eq3)[0]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 solve(eq3)[0]
#
# File ~/.local/lib/python3.8/site-packages/sympy/solvers/solvers.py:1095, in solve(f, *symbols, **flags)
#    1091 #
#    1092 # try to get a solution
#    1093 ###########################################################################
#    1094 if bare_f:
# -> 1095     solution = _solve(f[0], *symbols, **flags)
#    1096 else:
#    1097     solution = _solve_system(f, symbols, **flags)
#
# File ~/.local/lib/python3.8/site-packages/sympy/solvers/solvers.py:1709, in _solve(f, *symbols, **flags)
#    1706 # ----------- end of fallback ----------------------------
#    1708 if result is False:
# -> 1709     raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1711 if flags.get('simplify', True):
#    1712     result = list(map(simplify, result))
#
# NotImplementedError: multiple generators [exp(x), log(x), x**x]
# No algorithms are implemented to solve equation -x**x*(log(x) + 1) + exp(x)

# %%
# Flagging this issue on Sympy github repo.
